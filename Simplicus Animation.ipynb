# %% [markdown]
# ### Will Dodge September 2018

# %% [markdown]
# <h1 style="text-align:center">Animation</h1>

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import math

from matplotlib import animation, rc
from IPython.display import HTML, Image

# %%
def circle_xy(theta, origin_x, origin_y, radius):
    # origin at (h,k) with radius (r)
    
    # x = radius * np.cos(deg) + h
    # y = radius * np.sin(deg) + k
    x = radius * np.cos(theta) + origin_x 
    y = radius * np.sin(theta) + origin_y
       
    return x,y

# %%
theta = [i for i in np.linspace(0, 2*np.pi, 10)]

x,y = circle_xy(theta, -1, 3, 2)
x2,y2 = circle_xy(theta, -1, 3, 3)



fig, ax = plt.subplots(1,1, figsize=(10,10))

ax.plot(x,y)
ax.plot(x2,y2)

# %%
np.random.seed(917)

##### initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(j, theta, movement, slope, offset):
    
    origin_x = movement[j]
    origin_y = slope[j] * origin_x + offset[j]
    
    x,y = circle_xy(theta, origin_x,origin_y, 8)  
    
    line.set_data(x,y)
    ax.plot(x,y)
    
    return (line,)

n = 10

theta = np.linspace(0, 2*np.pi, 10)
movement = [i for i in range(-50,50,1)] * n
offset = [[i]*100 for i in np.random.uniform(-4,4,n)]
offset = [item for sublist in offset for item in sublist]
slope = [[i]*100 for i in np.random.uniform(-4,4,n)]
slope = [item for sublist in slope for item in sublist]

fargs = (theta,movement,slope,offset)

fig, ax = plt.subplots(1,1, figsize=(7,7))

line, = ax.plot([], [], lw=1)

ax.axis('off')
            
ax.set_xlim((-200, 200))
ax.set_ylim((-200, 200))

# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=1000, interval=200, blit=True, fargs=fargs)
anim.save('/home/will/animations/animation.gif', writer='imagemagick', fps=60)
# HTML(anim.to_html5_video())

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    
    # origin at (h,k) with radius (r)
    h = -1
    k = +3
    radius = 1
    theta = [i for i in np.linspace(0, 2*np.pi, 360)]
    
    # x = radius * np.cos(deg) + h
    # y = radius * np.sin(deg) + k
    x = [radius * np.cos(i) + h for i in theta]
    y = [radius * np.sin(i) + k for i in theta]
    
    x = x * 4
    y = y * 4
    
    x = x[i:]
    y = y[i:]
    
    line.set_data(x, y)
    return (line,)

fig, ax = plt.subplots(1,1, figsize=(7,7))

line, = ax.plot([], [], lw=1)

ax.axis('off')
            
ax.set_xlim(( -2, 2))
ax.set_ylim(( -2, 2))

# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=1000, interval=30, blit=True)
HTML(anim.to_html5_video())
#anim.save('basic_animation.mp4', fps=30)
