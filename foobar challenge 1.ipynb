# %%
### SOLUTION SPEED TESTS BELOW ###

# from timeit import Timer

# # solution 1

# setup1 = """

# x = [14, 27, 1, 4, 2, 50, 3, 1]
# y = [2, 4, -4, 3, 1, 1, 14, 27, 50]

# def answer1(x,y):
#     if len(x) > len(y):
#         a =list(set(x).difference(y))
#     else:
#         a =list(set(y).difference(x))
#     if len(a) ==1:
#         return a[0]
#     else:
#         return a

# """

# t = Timer("answer1(x,y)", setup = setup1)

# print(t.timeit()) # TIMES: 1.239030, 1.373639

# # solution 2

# setup2 = """

# xList = [14, 27, 1, 4, 2, 50, 3, 1]
# yList = [2, 4, -4, 3, 1, 1, 14, 27, 50]

# def answer2(xList, yList):
#     if len(xList) > len(yList):
#         a = [x for x in set(xList) if x not in set(yList)]
#     else:
#         a = [y for y in set(yList) if y not in set(xList)]
#     if len(a) ==1:
#         return a[0]
#     else:
#         return a

# """

# t = Timer("answer2(xList,yList)", setup=setup2)

# print(t.timeit()) # TIMES: 3.86234, 3.978035

# # solution 3

# setup3 = """

# xList = [14, 27, 1, 4, 2, 50, 3, 1]
# yList = [2, 4, -4, 3, 1, 1, 14, 27, 50]

# def answer3(xList, yList):
#     if len(xList) > len(yList):
#         a = [x for x in xList if x not in yList]
#     else:
#         a = [y for y in yList if y not in xList]
#     if len(a) ==1:
#         return a[0]
#     else:
#         return a

# """

# t = Timer("answer3(xList,yList)", setup=setup3)

# print(t.timeit()) # TIMES: 1.067349, 1.146500

x = [14, 27, 1, 4, 2, 50, 3, 1]
y = [2, 4, -4, 3, 1, 1, 14, 27, 50]

x = [14]
y = [14, 27]

def answer3(xList, yList):
    if len(xList) > len(yList):
        a = [x for x in xList if x not in yList]
    else:
        a = [y for y in yList if y not in xList]
    if len(a) ==1:
        return a[0]
    else:
        return a
answer3(x,y)
